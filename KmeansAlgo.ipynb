# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('kmeans.csv')
print("The shape of data is",df.shape)
df.head()
# Out:
# The shape of data is (15, 3)
#    Subject    A    B
# 0        1  1.0  1.0
# 1        2  1.5  2.0
# 2        3  3.0  4.0
# 3        4  5.0  7.0
# 4        5  3.5  5.0

# %%
import matplotlib.pyplot as plt
plt.scatter(df['A'],df['B'])

# %%
from sklearn.cluster import KMeans

# %%
wcss = []

for i in range(1,11):
    km = KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)
# Out:
# C:\Users\yashb\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1036: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
wcss
# Out:
# [400.86133333333333,
#  146.84589285714287,
#  90.64333333333333,
#  58.66416666666667,
#  45.291666666666664,
#  32.64833333333333,
#  22.295000000000005,
#  14.811666666666664,
#  11.069999999999999,
#  7.844999999999999]

# %%
plt.plot(range(1,11),wcss)

# %%
X = df.iloc[:,:].values
km = KMeans(n_clusters=4)
y_means = km.fit_predict(X)

# %%
y_means
# Out:
# array([2, 2, 2, 0, 0, 0, 0, 0, 3, 3, 1, 3, 1, 3, 1])

# %%
X[y_means == 3,1]
# Out:
# array([4.2, 6.5, 5.6, 5.8])

# %%
plt.scatter(X[y_means == 0,0],X[y_means == 0,1],color='blue')
plt.scatter(X[y_means == 1,0],X[y_means == 1,1],color='red')
plt.scatter(X[y_means == 2,0],X[y_means == 2,1],color='green')
plt.scatter(X[y_means == 3,0],X[y_means == 3,1],color='yellow')
